# %%
from espn_api.football import League
from collections import defaultdict
import pandas as pd
from ff_utils import owner_clean, load_game_data_from_csv, save_game_data_to_csv 
league_id = 800692
year = 2012
espn_s2="AECIWYgmieI54iV95TVm%2BL135zhJwAnVm9nOZsad1hBOfIEBU4%2FkXAK6mQ61M7xmIoMeITBWYTxDNGJhUbmi8WsARDuq6pmRADmrme1SwUgLsb%2B745GSuJWHIkmLeQoL4nBrBb3CHTExSRD8uIj0xuRlUSZXy12Lcm1YYa6Ha4G6ALVQH9uTmtn6b5XM%2B53qY34w6cPx02NhRgmsdOFGiW%2Bxte4j0f9OYnzGQmPvEV%2BV4lHwvBMMoIkBDE1LAMmTRn8%3D"
SWID="{8B19FBEC-AA6A-4006-99FB-ECAA6AF00669}"
YEARS = range(2012, 2023)

# %%
league = League(league_id, year, espn_s2=espn_s2, swid=SWID)
league_map = {}

# %%
print("league attributes",[att for att in dir(league) if '__' not in att] )
team = league.teams[0]
print("Teams attributes", [att for att in dir(team) if '__' not in att])
# Out:
# league attributes ['_abc_impl', '_fetch_draft', '_fetch_league', '_fetch_players', '_fetch_teams', '_get_all_pro_schedule', '_get_positional_ratings', '_get_pro_schedule', 'box_scores', 'currentMatchupPeriod', 'current_week', 'draft', 'espn_request', 'fetch_league', 'finalScoringPeriod', 'firstScoringPeriod', 'free_agents', 'get_team_data', 'league_id', 'least_scored_week', 'least_scorer', 'load_roster_week', 'logger', 'most_points_against', 'nfl_week', 'player_info', 'player_map', 'power_rankings', 'recent_activity', 'refresh', 'scoreboard', 'scoringPeriodId', 'settings', 'standings', 'teams', 'top_scored_week', 'top_scorer', 'year']
# Teams attributes ['_fetch_roster', '_fetch_schedule', '_get_winner', 'acquisition_budget_spent', 'acquisitions', 'division_id', 'division_name', 'draft_projected_rank', 'drops', 'final_standing', 'get_player_name', 'logo_url', 'losses', 'mov', 'outcomes', 'owner', 'playoff_pct', 'points_against', 'points_for', 'roster', 'schedule', 'scores', 'standing', 'streak_length', 'streak_type', 'team_abbrev', 'team_id', 'team_name', 'ties', 'trades', 'wins']

# %%
team_names = defaultdict(list)
for year in YEARS:
    if year in league_map:
        league = league_map[year]
    else:
        league = League(league_id, year, espn_s2=espn_s2, swid=SWID)
        league_map[year] = league
    for team in league.teams:
        if team.team_name not in team_names[team.owner]:
            team_names[team.owner].append(team.team_name)

# %%
team_names
# Out:
# defaultdict(list,
#             {'Adam Swietek': ['EZ Sweezy',
#               'Somewhere over Dwyane Bowe',
#               'Turn Down for  Watt'],
#              'Trond Liu': ['Ball So Hard',
#               'Morning Woodhead',
#               'Half Jap, Half Jew Children',
#               'Luck Her Right In The Percy',
#               'As opposed to  no sacko?!',
#               'Han For  Sacko!',
#               'Case of Ligma',
#               'Check His Papers',
#               'Mile high Hairline',
#               'Strip Club Talent Scouts',
#               'Sacko is only Thing he keeps'],
#              'Bhavuk Tandon': ['German Invasion',
#               'i JACQUIZZED on ur mom',
#               'Even the closet is bigger in TX',
#               'New Delhi Sacko Threepeat',
#               'Main st vs Wall st',
#               'TheBetter brown brother'],
#              'Alex Han': ['Team Han'],
#              'Matthew Coonrod': ['Team Master Baiters',
#               "Gronk if You're Horny",
#               'Dez Nutz',
#               'Coon Daddy'],
#              'Zack Havanec': ['Northern Aggression', 'Geico Trap'],
#              'Adam Kitain': ['Team Jewtopia',
#               'Team NYC Sour D',
#               'Team TLV Sour D',
#               'Team TLV Kush',
#               'Team Mile High',
#               'Team Miles High'],
#              'Scott Geary': ["My Couch Pulls  Out but I Don't",
#               "Hernandez's  Hit Men",
#               'Monday Night Drinking Club',
#               'Kip Schwartz'],
#              'Jake Wetherall': ['Team Dildo Gaggins'],
#              'Athan Cheokas': ['Team Cheokas', 'Artful Dodger'],
#              'Zachary Havanec': ['Geico Trap'],
#              'Arthur Cheokas': ['Artful Dodger'],
#              'Alexander Han': ['Team Han']})

# %%
league = league_map[2012]
matchup = league.scoreboard(week=2)[0]
print("matchup attributes",[att for att in dir(matchup) if '__' not in att] )
# Out:
# matchup attributes ['_fetch_matchup_info', 'away_score', 'away_team', 'data', 'home_score', 'home_team', 'is_playoff', 'matchup_type']

# %%
#THIS REGENERATES ALL HISTORIC DATA, takes ~60 seconds
# save_game_data_to_csv()

#THIS REGENERATES HISTORIC DATA FOR 1 SEASON
# save_gama_data_to_csv([2022])

# %%
at_df = load_game_data_from_csv()
reg_df = at_df[(at_df.is_playoff==False) & (at_df.result != 'NO CONTEST')]

# %%
## Lowest scoring game of all time
reg_df.sort_values('team_score').head(5)
# Out:
#     period             team           team_name         opponent  \
# 88       9   Jake Wetherall  Team Dildo Gaggins  Matthew Coonrod
# 83       9      Adam Kitain       Team TLV Kush        Trond Liu
# 65       7      Adam Kitain     Team NYC Sour D   Jake Wetherall
# 24       3  Matthew Coonrod          Coon Daddy    Athan Cheokas
# 3        1  Matthew Coonrod          Coon Daddy     Adam Swietek
#
#           opponent_name  team_score  opponent_score  differential  win  loss  \
# 88  Team Master Baiters        40.0           110.0          70.0    0     1
# 83        Case of Ligma        42.0           105.0          63.0    0     1
# 65   Team Dildo Gaggins        42.5           133.5          91.0    0     1
# 24        Artful Dodger        43.0            92.0          49.0    0     1
# 3             EZ Sweezy        45.0            86.0          41.0    0     1
#
#    result  is_playoff matchup_type  year
# 88   LOSS       False         NONE  2013
# 83   LOSS       False         NONE  2018
# 65   LOSS       False         NONE  2015
# 24   LOSS       False         NONE  2017
# 3    LOSS       False         NONE  2017

# %%
## Highest scoring game of all time
reg_df.sort_values('team_score', ascending=False).head(5)
# Out:
#     period            team                    team_name        opponent  \
# 41       5  Jake Wetherall           Team Dildo Gaggins     Scott Geary
# 13       2    Adam Swietek                    EZ Sweezy   Bhavuk Tandon
# 41       5     Adam Kitain                Team TLV Kush    Zack Havanec
# 38       4   Bhavuk Tandon           Main st vs Wall st  Jake Wetherall
# 77       8       Trond Liu  Half Jap, Half Jew Children        Alex Han
#
#                 opponent_name  team_score  opponent_score  differential  win  \
# 41               Kip Schwartz       166.0           111.0          55.0    1
# 13  New Delhi Sacko Threepeat       165.0            91.5          73.5    1
# 41                 Geico Trap       165.0           101.5          63.5    1
# 38         Team Dildo Gaggins       162.5            86.5          76.0    1
# 77                   Team Han       162.5           138.5          24.0    1
#
#     loss result  is_playoff matchup_type  year
# 41     0    WIN       False         NONE  2021
# 13     0    WIN       False         NONE  2015
# 41     0    WIN       False         NONE  2019
# 38     0    WIN       False         NONE  2020
# 77     0    WIN       False         NONE  2014

# %%
## Lowest scoring WIN of all time
win_df = reg_df[reg_df.result == 'WIN']
win_df.sort_values('team_score').head(5)
# Out:
#     period             team            team_name       opponent  \
# 80       9    Athan Cheokas        Artful Dodger       Alex Han
# 45       5  Matthew Coonrod  Team Master Baiters       Alex Han
# 21       3      Adam Kitain      Team NYC Sour D  Bhavuk Tandon
# 52       6     Zack Havanec           Geico Trap  Bhavuk Tandon
# 74       8      Adam Kitain      Team NYC Sour D   Adam Swietek
#
#                       opponent_name  team_score  opponent_score  differential  \
# 80                         Team Han        66.0            64.5           1.5
# 45                         Team Han        69.0            62.0           7.0
# 21  Even the closet is bigger in TX        69.0            68.0           1.0
# 52           i JACQUIZZED on ur mom        70.0            70.0           0.0
# 74       Somewhere over Dwyane Bowe        71.0            47.0          24.0
#
#     win  loss result  is_playoff matchup_type  year
# 80    1     0    WIN       False         NONE  2021
# 45    1     0    WIN       False         NONE  2013
# 21    1     0    WIN       False         NONE  2014
# 52    1     0    WIN       False         NONE  2013
# 74    1     0    WIN       False         NONE  2013

# %%
## Highest scoring LOSS of all time
loss_df = reg_df[reg_df.result == 'LOSS']
loss_df.sort_values('team_score', ascending=False).head(5)
# Out:
#     period           team        team_name     opponent  \
# 33       4    Scott Geary     Kip Schwartz     Alex Han
# 1        1  Athan Cheokas    Artful Dodger     Alex Han
# 76       8       Alex Han         Team Han    Trond Liu
# 95      10    Adam Kitain  Team NYC Sour D    Trond Liu
# 40       5   Zack Havanec       Geico Trap  Adam Kitain
#
#                   opponent_name  team_score  opponent_score  differential  \
# 33                     Team Han       142.5           153.5          11.0
# 1                      Team Han       139.5           155.0          15.5
# 76  Half Jap, Half Jew Children       138.5           162.5          24.0
# 95  Half Jap, Half Jew Children       134.5           161.0          26.5
# 40              Team NYC Sour D       134.5           146.0          11.5
#
#     win  loss result  is_playoff matchup_type  year
# 33    0     1   LOSS       False         NONE  2018
# 1     0     1   LOSS       False         NONE  2022
# 76    0     1   LOSS       False         NONE  2014
# 95    0     1   LOSS       False         NONE  2014
# 40    0     1   LOSS       False         NONE  2016

# %%
## All Time (Regular Season) Records
atr = reg_df.groupby('team').agg({'win': 'sum', 'loss': 'sum', 'team_score': 'sum', 'opponent_score': 'sum'}).reset_index()
atr['games_played'] = atr.win+atr.loss
atr['win_pct'] = atr.win / atr.games_played
atr['pf_pg'] = atr.team_score / atr.games_played
atr['pa_pg'] = atr.opponent_score / atr.games_played
atr.sort_values('win_pct')
# Out:
#               team  win  loss  team_score  opponent_score  games_played  \
# 4    Bhavuk Tandon   47    67     11455.0         11933.0           114
# 6  Matthew Coonrod   53    61     11415.0         11471.0           114
# 5   Jake Wetherall   49    55     10601.0         10368.5           104
# 0      Adam Kitain   56    58     11219.0         11731.0           114
# 1     Adam Swietek   56    58     11706.0         11659.0           114
# 8        Trond Liu   59    55     11658.5         11487.0           114
# 3    Athan Cheokas   54    50     10625.5         10512.0           104
# 9     Zack Havanec   60    54     11796.5         11788.0           114
# 7      Scott Geary   62    52     11944.0         11527.0           114
# 2         Alex Han   64    50     11663.0         11607.0           114
#
#     win_pct       pf_pg       pa_pg
# 4  0.412281  100.482456  104.675439
# 6  0.464912  100.131579  100.622807
# 5  0.471154  101.932692   99.697115
# 0  0.491228   98.412281  102.903509
# 1  0.491228  102.684211  102.271930
# 8  0.517544  102.267544  100.763158
# 3  0.519231  102.168269  101.076923
# 9  0.526316  103.478070  103.403509
# 7  0.543860  104.771930  101.114035
# 2  0.561404  102.307018  101.815789

# %%
## Most & Least Points For (normalized per game)
atr.sort_values('pf_pg')
# Out:
#               team  win  loss  team_score  opponent_score  games_played  \
# 0      Adam Kitain   56    58     11219.0         11731.0           114
# 6  Matthew Coonrod   53    61     11415.0         11471.0           114
# 4    Bhavuk Tandon   47    67     11455.0         11933.0           114
# 5   Jake Wetherall   49    55     10601.0         10368.5           104
# 3    Athan Cheokas   54    50     10625.5         10512.0           104
# 8        Trond Liu   59    55     11658.5         11487.0           114
# 2         Alex Han   64    50     11663.0         11607.0           114
# 1     Adam Swietek   56    58     11706.0         11659.0           114
# 9     Zack Havanec   60    54     11796.5         11788.0           114
# 7      Scott Geary   62    52     11944.0         11527.0           114
#
#     win_pct       pf_pg       pa_pg
# 0  0.491228   98.412281  102.903509
# 6  0.464912  100.131579  100.622807
# 4  0.412281  100.482456  104.675439
# 5  0.471154  101.932692   99.697115
# 3  0.519231  102.168269  101.076923
# 8  0.517544  102.267544  100.763158
# 2  0.561404  102.307018  101.815789
# 1  0.491228  102.684211  102.271930
# 9  0.526316  103.478070  103.403509
# 7  0.543860  104.771930  101.114035

# %%
## Most & Least Points Against (normalized per game)
atr.sort_values('pa_pg')
# Out:
#               team  win  loss  team_score  opponent_score  games_played  \
# 5   Jake Wetherall   49    55     10601.0         10368.5           104
# 6  Matthew Coonrod   53    61     11415.0         11471.0           114
# 8        Trond Liu   59    55     11658.5         11487.0           114
# 3    Athan Cheokas   54    50     10625.5         10512.0           104
# 7      Scott Geary   62    52     11944.0         11527.0           114
# 2         Alex Han   64    50     11663.0         11607.0           114
# 1     Adam Swietek   56    58     11706.0         11659.0           114
# 0      Adam Kitain   56    58     11219.0         11731.0           114
# 9     Zack Havanec   60    54     11796.5         11788.0           114
# 4    Bhavuk Tandon   47    67     11455.0         11933.0           114
#
#     win_pct       pf_pg       pa_pg
# 5  0.471154  101.932692   99.697115
# 6  0.464912  100.131579  100.622807
# 8  0.517544  102.267544  100.763158
# 3  0.519231  102.168269  101.076923
# 7  0.543860  104.771930  101.114035
# 2  0.561404  102.307018  101.815789
# 1  0.491228  102.684211  102.271930
# 0  0.491228   98.412281  102.903509
# 9  0.526316  103.478070  103.403509
# 4  0.412281  100.482456  104.675439
